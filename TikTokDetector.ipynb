# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from os.path import join
MY_GOOGLE_DRIVE_PATH = 'My Drive/ENGG 3130/TikTokDetector'
GIT_USERNAME = 'thatGuySid'
GIT_TOKEN = "ee76e946c4361c28fa7f2796e0defa151980a4b0"
GIT_REPOSITORY = "TikTokDetector"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

print("Project Path", PROJECT_PATH)

# !mkdir "{PROJECT_PATH}" 

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# Project Path /content/drive/My Drive/ENGG 3130/TikTokDetector
# GIT_PATH:  https://ee76e946c4361c28fa7f2796e0defa151980a4b0@github.com/thatGuySid/TikTokDetector.git

# %%
# %cd "{PROJECT_PATH}"
# !git clone "{GIT_PATH}"
# Out:
# /content/drive/My Drive/ENGG 3130/TikTokDetector
# Cloning into 'TikTokDetector'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %ls
# Out:
# TikTokDetector/

# %%
# !cd t
